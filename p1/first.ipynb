# %%
# %matplotlib inline
import matplotlib.pyplot as mpl
import numpy as np

# %%
x = np.linspace(0,10)
liney = mpl.plot(x, np.sin(x), '--', linewidth=2)
x = input("tell me something: ")
print("you wrote: " + x)
# Out:
# tell me something: fuggy
# you wrote: fuggy

# %% [markdown]
# $$\mathit{f}:[0,2]\rightarrow\mathbb{R}$$

# %% [markdown]
# \begin{equation}\mathit{f}'(a)=\frac{\mathit{f}(1)-\mathit{f}(0)}{1-0}=\frac{2-0}{1-0}=2\end{equation}

# %% [markdown]
# \begin{align*}c_{1}&\in[c,1]\\
# c_{2}&\in[\cos(1),c]\\
# c_{3}&\in[c,\cos(\cos(1))]\\
# c_{4}&\in[\cos(\cos(\cos(1))),1]\\
# &\vdots\\
# (1) c_{2n}&\in[\overbrace{\cos(\cos(\dots(1)))}^\text{2n-1 times},c] and\\
# (2) c_{2n+1}&\in[c,\overbrace{\cos(\cos(\dots(1)))}^\text{2n times}], \forall{n}\in\mathbb{N}\end{align*}
# Now, if the sequences defined by $b_{n}=\overbrace{\cos(\cos(\dots(1)))}^\text{2n times}$ and $a_{n}=\overbrace{\cos(\cos(\dots(1)))}^\text{2n+1 times}$ converge to $c$
